# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
data=pd.read_csv('/Users/irenakemives/Downloads/DS Course /Term Project/kaggle-survey-2017/multipleChoiceResponses.csv', encoding='ISO-8859-1', low_memory=False)

# %%
data.head()
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16716 entries, 0 to 16715
# Columns: 228 entries, GenderSelect to JobFactorPublishingOpportunity
# dtypes: float64(13), object(215)
# memory usage: 29.1+ MB

# %%
data.shape
# Out:
# (16716, 228)

# %%
data.dtypes
# Out:
# GenderSelect                                object
# Country                                     object
# Age                                        float64
# EmploymentStatus                            object
# StudentStatus                               object
# LearningDataScience                         object
# CodeWriter                                  object
# CareerSwitcher                              object
# CurrentJobTitleSelect                       object
# TitleFit                                    object
# CurrentEmployerType                         object
# MLToolNextYearSelect                        object
# MLMethodNextYearSelect                      object
# LanguageRecommendationSelect                object
# PublicDatasetsSelect                        object
# LearningPlatformSelect                      object
# LearningPlatformUsefulnessArxiv             object
# LearningPlatformUsefulnessBlogs             object
# ...

# %%
schema=pd.read_csv('/Users/irenakemives/Downloads/DS Course /Term Project/kaggle-survey-2017/schema.csv', encoding='ISO-8859-1', low_memory=False)

schema.head(300)
# Out:
#                                 Column  \
# 0                         GenderSelect
# 1                       GenderFreeForm
# 2                              Country
# 3                                  Age
# 4                     EmploymentStatus
# 5                        StudentStatus
# 6                  LearningDataScience
# 7             KaggleMotivationFreeForm
# 8                           CodeWriter
# 9                       CareerSwitcher
# 10               CurrentJobTitleSelect
# 11             CurrentJobTitleFreeForm
# 12                            TitleFit
# 13                 CurrentEmployerType
# 14                MLToolNextYearSelect
# 15              MLToolNextYearFreeForm
# 16              MLMethodNextYearSelect
# 17            MLMethodNextYearFreeForm
# 18        LanguageRecommendationSelect
# 19      LanguageRecommendationFreeForm
# 20                PublicDatasetsSelect
# 21              PublicDatasetsFreeForm
# 22   PersonalProjectsChallengeFreeForm
# ...

# %%
data['PublicDatasetsSelect'].describe()
# Out:
# count                                                 10796
# unique                                                  114
# top       Dataset aggregator/platform (i.e. Socrata/Kagg...
# freq                                                   2950
# Name: PublicDatasetsSelect, dtype: object

# %%
data['GenderSelect'].describe()
# Out:
# count     16621
# unique        4
# top        Male
# freq      13610
# Name: GenderSelect, dtype: object

# %%
data['GenderSelect'].count()
# Out:
# 16621

# %%
print(data['GenderSelect'].value_counts(normalize=True))
# Out:
# Male                                                 0.818844
# Female                                               0.167138
# A different identity                                 0.009566
# Non-binary, genderqueer, or gender non-conforming    0.004452
# Name: GenderSelect, dtype: float64

# %%
print(data['GenderSelect'].value_counts())
# Out:
# Male                                                 13610
# Female                                                2778
# A different identity                                   159
# Non-binary, genderqueer, or gender non-conforming       74
# Name: GenderSelect, dtype: int64

# %%
print(data['Country'].value_counts(normalize=True))
# Out:
# United States                  0.252908
# India                          0.162941
# Other                          0.061645
# Russia                         0.034830
# United Kingdom                 0.032239
# People 's Republic of China    0.028382
# Brazil                         0.028020
# Germany                        0.027719
# France                         0.026635
# Canada                         0.026514
# Australia                      0.025369
# Spain                          0.019283
# Japan                          0.016692
# Taiwan                         0.015306
# Italy                          0.014342
# Netherlands                    0.012353
# Ukraine                        0.011811
# South Korea                    0.011690
# Singapore                      0.011088
# Poland                         0.011088
# Pakistan                       0.009702
# Turkey                         0.008677
# Indonesia                      0.007894
# ...

# %%
#print(data['CompensationCurrency'].value_counts(normalize=True))

# %%
rates=pd.read_csv('/Users/irenakemives/Downloads/DS Course /Term Project/kaggle-survey-2017/conversionRates.csv', encoding='ISO-8859-1', low_memory=False)

# %%
rates.head(20)
# Out:
#     Unnamed: 0 originCountry  exchangeRate
# 0            1           USD      1.000000
# 1            2           EUR      1.195826
# 2            3           INR      0.015620
# 3            4           GBP      1.324188
# 4            5           BRL      0.321350
# 5            6           RUB      0.017402
# 6            7           CAD      0.823688
# 7            8           AUD      0.802310
# 8            9           JPY      0.009108
# 9           10           CNY      0.153000
# 10          11           PLN      0.281104
# 11          12           SGD      0.742589
# 12          13           ZAR      0.077002
# 13          14           CHF      1.043382
# 14          15           MXN      0.056414
# 15          16           TWD      0.033304
# 16          17           COP      0.000342
# 17          18           PKR      0.009476
# 18          19           TRY      0.291780
# 19          20           DKK      0.160730

# %%
rates['originCountry'].describe()
# Out:
# count      86
# unique     86
# top       GTQ
# freq        1
# Name: originCountry, dtype: object

# %%
data.groupby('GenderSelect')['Age'].mean().plot(kind='bar')
plt.show()

# %%
#data.groupby('GenderSelect')['Age'].mean().plot.bar(rot=0)
#plt.show()

# %%
data['Age'].describe()
# Out:
# count    16385.000000
# mean        32.372841
# std         10.473487
# min          0.000000
# 25%         25.000000
# 50%         30.000000
# 75%         37.000000
# max        100.000000
# Name: Age, dtype: float64

# %%
data['CompensationAmount'].describe()
# Out:
# count       5224
# unique       906
# top       100000
# freq         151
# Name: CompensationAmount, dtype: object

# %%
data['GenderSelect']=data['GenderSelect'].replace({"Non-binary, genderqueer, or gender non-conforming": "Other","A different identity":"Other"})

# %%
data.tail(100)
# Out:
#       GenderSelect                      Country   Age  \
# 16616        Other                        Kenya  25.0
# 16617       Female                        Egypt  45.0
# 16618       Female                United States  44.0
# 16619         Male                        Other  27.0
# 16620       Female                United States   NaN
# 16621         Male                       Poland  41.0
# 16622         Male                        Italy  49.0
# 16623         Male  People 's Republic of China  37.0
# 16624         Male                      Germany  27.0
# 16625         Male                United States  39.0
# 16626       Female                        India  20.0
# 16627         Male               United Kingdom  43.0
# 16628         Male                        Spain  25.0
# 16629         Male                        Japan  49.0
# 16630         Male                United States  27.0
# 16631       Female                United States  41.0
# ...

# %%
print(data['GenderSelect'].value_counts(normalize=True))
# Out:
# Male      0.818844
# Female    0.167138
# Other     0.014018
# Name: GenderSelect, dtype: float64

# %%
#currency conversion

# %%
#CompensationAmount
#CompensationCurrency
#exchangeRate

# %%
data['CompensationCurrency'].describe()
# Out:
# count     4530
# unique      87
# top        USD
# freq      1577
# Name: CompensationCurrency, dtype: object

# %%
data['CompensationAmount'].describe()
# Out:
# count       5224
# unique       906
# top       100000
# freq         151
# Name: CompensationAmount, dtype: object

# %%
rates['exchangeRate'].describe()
# Out:
# count    86.000000
# mean      0.281922
# std       0.498894
# min       0.000030
# 25%       0.009179
# 50%       0.057550
# 75%       0.282506
# max       2.652053
# Name: exchangeRate, dtype: float64

# %%
data['CompensationAmount'].describe()
# Out:
# count       5224
# unique       906
# top       100000
# freq         151
# Name: CompensationAmount, dtype: object

# %%
rates.head()
# Out:
#    Unnamed: 0 originCountry  exchangeRate
# 0           1           USD      1.000000
# 1           2           EUR      1.195826
# 2           3           INR      0.015620
# 3           4           GBP      1.324188
# 4           5           BRL      0.321350

# %%
rates.rename(columns={'originCountry':'CompensationCurrency'}, inplace=True)

# %%
rates.head(30)
# Out:
#     Unnamed: 0 CompensationCurrency  exchangeRate
# 0            1                  USD      1.000000
# 1            2                  EUR      1.195826
# 2            3                  INR      0.015620
# 3            4                  GBP      1.324188
# 4            5                  BRL      0.321350
# 5            6                  RUB      0.017402
# 6            7                  CAD      0.823688
# 7            8                  AUD      0.802310
# 8            9                  JPY      0.009108
# 9           10                  CNY      0.153000
# 10          11                  PLN      0.281104
# 11          12                  SGD      0.742589
# 12          13                  ZAR      0.077002
# 13          14                  CHF      1.043382
# 14          15                  MXN      0.056414
# 15          16                  TWD      0.033304
# 16          17                  COP      0.000342
# 17          18                  PKR      0.009476
# ...

# %%
data2=data.merge(rates,on='CompensationCurrency')

# %%
data2.head(300)
# Out:
#     GenderSelect                      Country   Age  \
# 0           Male                United States  56.0
# 1           Male                United States  25.0
# 2           Male                United States  33.0
# 3           Male                United States  35.0
# 4           Male                       Sweden  37.0
# 5           Male                         Iran  31.0
# 6           Male                United States  40.0
# 7         Female                United States  31.0
# 8         Female                United States  39.0
# 9         Female                United States  30.0
# 10          Male                United States  50.0
# 11          Male                United States  59.0
# 12          Male                        Other  28.0
# 13          Male                United States  49.0
# 14          Male                United States  62.0
# 15          Male                United States  38.0
# 16          Male                United States  27.0
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4529 entries, 0 to 4528
# Columns: 230 entries, GenderSelect to exchangeRate
# dtypes: float64(14), int64(1), object(215)
# memory usage: 8.0+ MB

# %%
data2['CompensationAmount'].describe()
# Out:
# count       4376
# unique       827
# top       100000
# freq         121
# Name: CompensationAmount, dtype: object

# %%
data2['CompensationAmount']= data2['CompensationAmount'].iloc[:].str.replace(',','')

# %%
data2['CompensationAmount']= data2['CompensationAmount'].iloc[:].str.replace('-','')

# %%
data2['CompensationAmount'].isnull().sum()
# Out:
# 153

# %%
data2['exchangeRate'].isnull().sum()
# Out:
# 0

# %%
data2=data2.dropna(subset = ['CompensationAmount'])

# %%
data2['CompensationAmount'].isnull().sum()
# Out:
# 0

# %%
#data2 only has respondents with income infomation. Used for income analysis

# %%
data2.tail()
# Out:
#      GenderSelect    Country   Age    EmploymentStatus StudentStatus  \
# 4524         Male      Other  33.0  Employed full-time           NaN
# 4525         Male      Other  34.0  Employed full-time           NaN
# 4526       Female  Argentina  28.0  Employed full-time           NaN
# 4527         Male      Other  31.0  Employed part-time           NaN
# 4528         Male      Other  47.0  Employed full-time           NaN
#
#      LearningDataScience CodeWriter CareerSwitcher CurrentJobTitleSelect  \
# 4524                 NaN        Yes            NaN      Business Analyst
# 4525                 NaN        Yes            NaN      Business Analyst
# 4526                 NaN        Yes            NaN              Engineer
# 4527                 NaN        Yes            NaN            Researcher
# 4528                 NaN        Yes            NaN    Computer Scientist
#
#      TitleFit     ...      JobFactorTitle JobFactorCompanyFunding  \
# ...

# %%
data2['CompConverted']=pd.to_numeric(data2['CompensationAmount'])

# %%
data2['CompConverted'].describe()
# Out:
# count    4.373000e+03
# mean     4.887385e+07
# std      2.138544e+09
# min      0.000000e+00
# 25%      5.000000e+04
# 50%      9.960000e+04
# 75%      2.180000e+05
# max      1.000000e+11
# Name: CompConverted, dtype: float64

# %%
data2.describe()
# Out:
#                Age  LearningCategorySelftTaught  \
# count  4349.000000                  4365.000000
# mean     34.119568                    33.041695
# std       9.575174                    24.541594
# min       0.000000                     0.000000
# 25%      27.000000                    15.000000
# 50%      32.000000                    30.000000
# 75%      39.000000                    50.000000
# max     100.000000                   100.000000
#
#        LearningCategoryOnlineCourses  LearningCategoryWork  \
# count                    4369.000000           4371.000000
# mean                       23.472076             20.246595
# std                        23.447820             19.697511
# min                         0.000000              0.000000
# 25%                         5.000000              0.000000
# 50%                        20.000000             20.000000
# 75%                        35.000000             30.000000
# ...

# %%
data2['Salary_USD']=data2['CompConverted']*data2['exchangeRate']

#CompensationAmount
#CompensationCurrency
#exchangeRate

# %%
data2.head(20)
# Out:
#    GenderSelect        Country   Age  \
# 0          Male  United States  56.0
# 1          Male  United States  25.0
# 2          Male  United States  33.0
# 3          Male  United States  35.0
# 4          Male         Sweden  37.0
# 5          Male           Iran  31.0
# 6          Male  United States  40.0
# 7        Female  United States  31.0
# 8        Female  United States  39.0
# 9        Female  United States  30.0
# 10         Male  United States  50.0
# 11         Male  United States  59.0
# 12         Male          Other  28.0
# 13         Male  United States  49.0
# 14         Male  United States  62.0
# 15         Male  United States  38.0
# 16         Male  United States  27.0
# 17        Other         Canada  23.0
# 18       Female  United States  31.0
# 19       Female  United States  31.0
#
#                                      EmploymentStatus StudentStatus  \
# 0   Independent contractor, freelancer, or self-em...           NaN
# ...

# %%
def income(row):
    if row ["Salary_USD"] <=20000:
        return "$20,000 or less"
    elif 20000<(row["Salary_USD"])<=40000:
        return "$20,001-$40,000"
    elif 40000<(row["Salary_USD"])<=60000:
        return "$40,001-$60,000"
    elif 60000<(row["Salary_USD"])<=80000:
        return "$60,001-$80,000"
    elif 80000<(row["Salary_USD"])<=100000:
        return "$80,001-$100,000"
    elif 100000<(row["Salary_USD"])<=150000:
        return "$100,001-$150,000"
    elif 150000<(row["Salary_USD"])<=200000:
        return "$150,001-$200,000"
    elif 200000<(row["Salary_USD"])<=999999999:
        return "Over $200,000"

data2 = data2.assign(income_group=data2.apply(income, axis=1))

data2.head(50)
# Out:
#    GenderSelect         Country   Age  \
# 0          Male   United States  56.0
# 1          Male   United States  25.0
# 2          Male   United States  33.0
# 3          Male   United States  35.0
# 4          Male          Sweden  37.0
# 5          Male            Iran  31.0
# 6          Male   United States  40.0
# 7        Female   United States  31.0
# 8        Female   United States  39.0
# 9        Female   United States  30.0
# 10         Male   United States  50.0
# 11         Male   United States  59.0
# 12         Male           Other  28.0
# 13         Male   United States  49.0
# 14         Male   United States  62.0
# 15         Male   United States  38.0
# 16         Male   United States  27.0
# 17        Other          Canada  23.0
# 18       Female   United States  31.0
# 19       Female   United States  31.0
# 20         Male   United States  50.0
# 21         Male   United States  72.0
# 22         Male   United States  37.0
# ...

# %%
data2.drop(data2[data2.Salary_USD > 300000].index, inplace=True)

# %%
data2.drop(data2[data2.Salary_USD == 0].index, inplace=True)

# %%
data2.groupby('GenderSelect')['Salary_USD'].mean().plot.bar(rot=0)
plt.show()

# %%
data2.Salary_USD.mean()
# Out:
# 65119.4663955447

# %%
data2['Salary_USD'].describe()
# Out:
# count      4297.000000
# mean      65119.466396
# std       54756.157575
# min           0.060000
# 25%       21415.200000
# 50%       53812.170000
# 75%       95666.080000
# max      300000.000000
# Name: Salary_USD, dtype: float64

# %%
data2['Salary_USD'].isnull().sum()
# Out:
# 3

# %%
data2=data2.dropna(subset = ['Salary_USD'])

# %%
data2['Salary_USD'].isnull().sum()
# Out:
# 0

# %%
#data2['Salary_USD']=data2['Salary_USD'].astype(int)#

# %%
data2['income_group'].describe()
# Out:
# count                4297
# unique                  8
# top       $20,000 or less
# freq                 1037
# Name: income_group, dtype: object

# %%
data2.groupby("income_group").size().plot(kind="bar")

# %%
data2.Salary_USD.mean()
# Out:
# 75597.22445029124

# %%
data2.groupby('income_group')['Salary_USD'].mean().plot(kind='bar')
data2.groupby('income_group')['Salary_USD'].mean().plot(kind='bar')
plt.show()plt.show()

# %%
data2.groupby('CurrentJobTitleSelect')['Salary_USD'].mean().plot(kind='bar',figsize=(15,15))
plt.show()

# %%
data2.groupby('CurrentEmployerType')['Salary_USD'].mean().plot(kind='bar',figsize=(10,12))
plt.show()
